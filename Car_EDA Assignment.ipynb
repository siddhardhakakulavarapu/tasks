# %% [markdown]
# # car_EDA Assignment

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\siddh\python\Downloads\car_df_EDA.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0         make fuel_type aspiration num_of_doors  \
# 0               0           1  alfa-romero       gas        std          two
# 1               1           2  alfa-romero       gas        std          two
# 2               2           3  alfa-romero       gas        std          two
# 3               3           4         audi       gas        std         four
# 4               4           5         audi       gas        std         four
# ..            ...         ...          ...       ...        ...          ...
# 203           203         204        volvo    diesel      turbo         four
# 204           204         205        volvo       gas      turbo         four
# 205           202         203        volvo       gas        std         four
# 206           203         204        volvo    diesel      turbo         four
# 207           204         205        volvo       gas      turbo         four
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'make', 'fuel_type', 'aspiration',
#        'num_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'compression_ratio',
#        'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0'],axis = 1,inplace = True)

# %%
df
# Out:
#             make fuel_type aspiration num_of_doors   body_style drive_wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
# 205        volvo       gas        std         four        sedan          rwd
# 206        volvo    diesel      turbo         four        sedan          rwd
# 207        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
df[df.duplicated()]
# Out:
#       make fuel_type aspiration num_of_doors body_style drive_wheels  \
# 205  volvo       gas        std         four      sedan          rwd
# 206  volvo    diesel      turbo         four      sedan          rwd
# 207  volvo       gas      turbo         four      sedan          rwd
#
#     engine_location  wheel_base  length  width  ...  engine_type  \
# 205           front       109.1   188.8   68.9  ...         ohcv
# 206           front       109.1   188.8   68.9  ...          ohc
# 207           front       109.1   188.8   68.9  ...          ohc
#
#      num_of_cylinders engine_size fuel_system  compression_ratio horsepower  \
# 205               six       173.0        mpfi                8.8        134
# 206               six       145.0         idi               23.0        106
# 207              four       141.0        mpfi                9.5        114
#
#      peak_rpm city_mpg highway_mpg  price
# 205      5500       18          23  21485
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               208 non-null    object
#  1   fuel_type          208 non-null    object
#  2   aspiration         208 non-null    object
#  3   num_of_doors       208 non-null    object
#  4   body_style         208 non-null    object
#  5   drive_wheels       208 non-null    object
#  6   engine_location    208 non-null    object
#  7   wheel_base         206 non-null    float64
#  8   length             208 non-null    float64
#  9   width              208 non-null    float64
#  10  height             208 non-null    float64
#  11  curb_weight        208 non-null    int64
#  12  engine_type        207 non-null    object
#  13  num_of_cylinders   208 non-null    object
#  14  engine_size        206 non-null    float64
#  15  fuel_system        208 non-null    object
# ...

# %%
df.drop_duplicates(keep = 'first',inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 0 to 204
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               205 non-null    object
#  1   fuel_type          205 non-null    object
#  2   aspiration         205 non-null    object
#  3   num_of_doors       205 non-null    object
#  4   body_style         205 non-null    object
#  5   drive_wheels       205 non-null    object
#  6   engine_location    205 non-null    object
#  7   wheel_base         203 non-null    float64
#  8   length             205 non-null    float64
#  9   width              205 non-null    float64
#  10  height             205 non-null    float64
#  11  curb_weight        205 non-null    int64
#  12  engine_type        204 non-null    object
#  13  num_of_cylinders   205 non-null    object
#  14  engine_size        203 non-null    float64
#  15  fuel_system        205 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           2
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          1
# num_of_cylinders     0
# engine_size          2
# fuel_system          0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                3
# dtype: int64

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df['fuel_type'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df['num_of_doors'].unique()
# Out:
# array(['two', 'four', '?'], dtype=object)

# %%
df['num_of_doors'] = df['num_of_doors'].replace('?',np.nan)

# %%
df['num_of_doors'].mode()
# Out:
# 0    four
# Name: num_of_doors, dtype: object

# %%
df['num_of_doors'].fillna(df['num_of_doors'].mode()[0],inplace = True)

# %%
df['num_of_doors'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
def door(n):
    if n == 'two':
        return 2
    else:
        return 4

# %%
df['num_of_doors'] = df['num_of_doors'].apply(door)

# %%
df['num_of_doors']
# Out:
# 0      2
# 1      2
# 2      2
# 3      4
# 4      4
#       ..
# 200    4
# 201    4
# 202    4
# 203    4
# 204    4
# Name: num_of_doors, Length: 205, dtype: int64

# %%
df['num_of_doors'].unique()
# Out:
# array([2, 4], dtype=int64)

# %%
df['body_style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df['drive_wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df['engine_location'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
df['wheel_base'].unique()
# Out:
# array([ 88.6,  94.5,  99.8,  99.4, 105.8,  99.5, 101.2,   nan, 103.5,
#        110. ,  88.4,  93.7, 103.3,  95.9,  86.6,  96.5,  94.3,  96. ,
#        113. , 102. ,  93.1,  95.3,  98.8, 104.9, 106.7, 115.6,  96.6,
#        120.9, 112. , 102.7,  93. ,  96.3,  95.1,  97.2, 100.4,  91.3,
#         99.2, 107.9, 114.2, 108. ,  89.5,  98.4,  96.1,  99.1,  93.3,
#         97. ,  96.9,  95.7, 102.4, 102.9, 104.5,  97.3, 104.3, 109.1])

# %%
df['wheel_base'].isna().sum()
# Out:
# 2

# %%
df['wheel_base'].fillna(df['wheel_base'].median(),inplace = True)

# %%
df['wheel_base'].unique()
# Out:
# array([ 88.6,  94.5,  99.8,  99.4, 105.8,  99.5, 101.2,  97. , 103.5,
#        110. ,  88.4,  93.7, 103.3,  95.9,  86.6,  96.5,  94.3,  96. ,
#        113. , 102. ,  93.1,  95.3,  98.8, 104.9, 106.7, 115.6,  96.6,
#        120.9, 112. , 102.7,  93. ,  96.3,  95.1,  97.2, 100.4,  91.3,
#         99.2, 107.9, 114.2, 108. ,  89.5,  98.4,  96.1,  99.1,  93.3,
#         96.9,  95.7, 102.4, 102.9, 104.5,  97.3, 104.3, 109.1])

# %%
df['length'].unique()
# Out:
# array([168.8, 171.2, 176.6, 177.3, 192.7, 178.2, 176.8, 189. , 193.8,
#        197. , 141.1, 155.9, 158.8, 157.3, 174.6, 173.2, 144.6, 150. ,
#        163.4, 157.1, 167.5, 175.4, 169.1, 170.7, 172.6, 199.6, 191.7,
#        159.1, 166.8, 169. , 177.8, 175. , 190.9, 187.5, 202.6, 180.3,
#        208.1, 199.2, 178.4, 173. , 172.4, 165.3, 170.2, 165.6, 162.4,
#        173.4, 181.7, 184.6, 178.5, 186.7, 198.9, 167.3, 168.9, 175.7,
#        181.5, 186.6, 156.9, 157.9, 172. , 173.5, 173.6, 158.7, 169.7,
#        166.3, 168.7, 176.2, 175.6, 183.5, 187.8, 171.7, 159.3, 165.7,
#        180.2, 183.1, 188.8])

# %%
df['width'].unique()
# Out:
# array([64.1, 65.5, 66.2, 66.4, 66.3, 71.4, 67.9, 64.8, 66.9, 70.9, 60.3,
#        63.6, 63.8, 64.6, 63.9, 64. , 65.2, 62.5, 66. , 61.8, 69.6, 70.6,
#        64.2, 65.7, 66.5, 66.1, 70.3, 71.7, 70.5, 72. , 68. , 64.4, 65.4,
#        68.4, 68.3, 65. , 72.3, 66.6, 63.4, 65.6, 67.7, 67.2, 68.9, 68.8])

# %%
df['height'].unique()
# Out:
# array([48.8, 52.4, 54.3, 53.1, 55.7, 55.9, 52. , 53.7, 56.3, 53.2, 50.8,
#        50.6, 59.8, 50.2, 52.6, 54.5, 58.3, 53.3, 54.1, 51. , 53.5, 51.4,
#        52.8, 47.8, 49.6, 55.5, 54.4, 56.5, 58.7, 54.9, 56.7, 55.4, 54.8,
#        49.4, 51.6, 54.7, 55.1, 56.1, 49.7, 56. , 50.5, 55.2, 52.5, 53. ,
#        59.1, 53.9, 55.6, 56.2, 57.5])

# %%
df['curb_weight'].unique()
# Out:
# array([2548, 2823, 2337, 2824, 2507, 2844, 2954, 3086, 3053, 2395, 2710,
#        2765, 3055, 3230, 3380, 3505, 1488, 1874, 1909, 1876, 2128, 1967,
#        1989, 2191, 2535, 2811, 1713, 1819, 1837, 1940, 1956, 2010, 2024,
#        2236, 2289, 2304, 2372, 2465, 2293, 2734, 4066, 3950, 1890, 1900,
#        1905, 1945, 1950, 2380, 2385, 2500, 2410, 2443, 2425, 2670, 2700,
#        3515, 3750, 3495, 3770, 3740, 3685, 3900, 3715, 2910, 1918, 1944,
#        2004, 2145, 2370, 2328, 2833, 2921, 2926, 2365, 2405, 2403, 1889,
#        2017, 1938, 1951, 2028, 1971, 2037, 2008, 2324, 2302, 3095, 3296,
#        3060, 3071, 3139, 3020, 3197, 3430, 3075, 3252, 3285, 3485, 3130,
#        2818, 2778, 2756, 2800, 3366, 2579, 2460, 2658, 2695, 2707, 2758,
#        2808, 2847, 2050, 2120, 2240, 2190, 2340, 2510, 2290, 2455, 2420,
#        2650, 1985, 2040, 2015, 2280, 3110, 2081, 2109, 2275, 2094, 2122,
#        2140, 2169, 2204, 2265, 2300, 2540, 2536, 2551, 2679, 2714, 2975,
# ...

# %%
df['engine_type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', nan, 'ohcf', 'dohcv'],
#       dtype=object)

# %%
df['engine_type'].fillna(df['engine_type'].mode()[0],inplace = True)

# %%
df['engine_type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df['num_of_cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
def cyl(n):
    if n == 'two':
        return 2
    elif n == 'three':
        return 3
    elif n == 'four':
        return 4
    elif n == 'five':
        return 5
    elif n == 'six':
        return 6
    elif n == 'eight':
        return 8
    else:
        return 12

# %%
df['num_of_cylinders'] = df['num_of_cylinders'].apply(cyl)

# %%
df['num_of_cylinders'].unique()
# Out:
# array([ 4,  6,  5,  3, 12,  2,  8], dtype=int64)

# %%
df['engine_size'].unique()
# Out:
# array([130., 152., 109., 136., 131., 108., 164., 209.,  61.,  90.,  98.,
#        122., 156.,  92.,  79., 110.,  nan, 111., 119., 258., 326.,  91.,
#         70.,  80., 140., 134., 183., 234., 308., 304.,  97., 103., 120.,
#        181., 151., 194., 203., 132., 121., 146., 171., 161., 141., 173.,
#        145.])

# %%
df['num_of_cylinders'] = df['num_of_cylinders'].astype('int8')

# %%
df['engine_size'].fillna(df['engine_size'].median(),inplace = True)

# %%
df['fuel_system'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
df['compression_ratio'].unique()
# Out:
# array([ 9.  , 10.  ,  8.  ,  8.5 ,  8.3 ,  7.  ,  8.8 ,  9.5 ,  9.6 ,
#         9.41,  9.4 ,  7.6 ,  9.2 , 10.1 ,  9.1 ,  8.1 , 11.5 ,  8.6 ,
#        22.7 , 22.  , 21.5 ,  7.5 , 21.9 ,  7.8 ,  8.4 , 21.  ,  8.7 ,
#         9.31,  9.3 ,  7.7 , 22.5 , 23.  ])

# %%
df['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', '?', '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df['horsepower'] = df['horsepower'].replace('?',np.nan)

# %%
df['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', nan, '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df['horsepower'].fillna(df['horsepower'].median(),inplace = True)

# %%
df['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', 95.0, '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df['horsepower'] = df['horsepower'].astype('int16')

# %%
df['horsepower'].unique()
# Out:
# array([111, 154, 102, 115, 110, 140, 160, 101, 121, 182,  48,  70,  68,
#         88, 145,  58,  76,  60,  86, 100,  78,  90, 176, 262, 135,  84,
#         64, 120,  72, 123, 155, 184, 175, 116,  69,  55,  97, 152, 200,
#         95, 142, 143, 207, 288,  73,  82,  94,  62,  56, 112,  92, 161,
#        156,  52,  85, 114, 162, 134, 106], dtype=int16)

# %%
df['peak_rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', '?', '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
df['peak_rpm'] = df['peak_rpm'].replace('?',np.nan)

# %%
df['peak_rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', nan, '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
df['peak_rpm'].fillna(df['peak_rpm'].median(),inplace = True)

# %%
df['peak_rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', 5200.0, '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
df['peak_rpm'] = df['peak_rpm'].astype('int16')

# %%
df['peak_rpm'].unique()
# Out:
# array([5000, 5500, 5800, 4250, 5400, 5100, 4800, 6000, 4750, 4650, 4200,
#        4350, 4500, 5200, 4150, 5600, 5900, 5750, 5250, 4900, 4400, 6600,
#        5300], dtype=int16)

# %%
df['city_mpg'].unique()
# Out:
# array([21, 19, 24, 18, 17, 16, 23, 20, 15, 47, 38, 37, 31, 49, 30, 27, 25,
#        13, 26, 36, 22, 14, 45, 28, 32, 35, 34, 29, 33], dtype=int64)

# %%
df['highway_mpg'].unique()
# Out:
# array([27, 26, 30, 22, 25, 20, 29, 28, 53, 43, 41, 38, 24, 54, 42, 34, 33,
#        31, 19, 17, 23, 32, 39, 18, 16, 37, 50, 36, 47, 46], dtype=int64)

# %%
df['price'].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', '?', '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', nan, '35550', '36000', '5195',
#        '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#        '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#        '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#        '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#        '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#        '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#        '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %%
df['price'] = df['price'].replace('?',np.nan)

# %%
df['price'].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', nan, '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', '35550', '36000', '5195',
#        '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#        '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#        '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#        '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#        '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#        '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#        '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %%
df['price'].fillna(df['price'].median(),inplace = True)

# %%
df['price'] = df['price'].astype('int64')

# %%
df['price'].unique()
# Out:
# array([13495, 16500, 13950, 17450, 15250, 17710, 18920, 23875, 10221,
#        16430, 16925, 20970, 21105, 24565, 30760, 41315, 36880,  5151,
#         6295,  6575,  5572,  6377,  7957,  6229,  6692,  7609,  8558,
#         8921, 12964,  6479,  6855,  5399,  6529,  7129,  7295,  7895,
#         9095,  8845, 10295, 12945, 10345,  6785, 11048, 35550, 36000,
#         5195,  6095,  6795,  6695,  7395, 10945, 11845, 13645, 15645,
#         8495, 10595, 10245, 10795, 11245, 18280, 18344, 25552, 28248,
#        28176, 31600, 34184, 35056, 40960, 45400, 16503,  5389,  6189,
#         6669,  7689,  9959,  8499, 12629, 14869, 14489,  6989,  8189,
#         9279,  5499,  7099,  6649,  6849,  7349,  7299,  7799,  7499,
#         7999,  8249,  8949,  9549, 13499, 14399, 17199, 19699, 18399,
#        11900, 13200, 12440, 13860, 15580, 16695, 17075, 16630, 17950,
#        18150, 12764, 22018, 32528, 34028, 37028,  9295,  9895, 11850,
# ...

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors           int64
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders        int8
# engine_size          float64
# fuel_system           object
# compression_ratio    float64
# horsepower             int16
# peak_rpm               int16
# city_mpg               int64
# highway_mpg            int64
# price                  int64
# dtype: object

# %%
df
# Out:
#             make fuel_type aspiration  num_of_doors   body_style drive_wheels  \
# 0    alfa-romero       gas        std             2  convertible          rwd
# 1    alfa-romero       gas        std             2  convertible          rwd
# 2    alfa-romero       gas        std             2    hatchback          rwd
# 3           audi       gas        std             4        sedan          fwd
# 4           audi       gas        std             4        sedan          4wd
# ..           ...       ...        ...           ...          ...          ...
# 200        volvo       gas        std             4        sedan          rwd
# 201        volvo       gas      turbo             4        sedan          rwd
# 202        volvo       gas        std             4        sedan          rwd
# 203        volvo    diesel      turbo             4        sedan          rwd
# 204        volvo       gas      turbo             4        sedan          rwd
#
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('bmh')

# %% [markdown]
# ## Numerical

# %% [markdown]
# ### Histogram

# %%
df['num_of_doors'].plot(kind = 'hist',xlabel = 'Number of doors',figsize = (6,4),color = '#32a8a0')
# Out:
# <Axes: xlabel='Number of doors', ylabel='Frequency'>

# %% [markdown]
# * There are more cars (120 cars) with 4 doors compared to 2 doored cars (90 cars) in the given data set

# %%
df['wheel_base'].plot(kind = 'hist',xlabel = 'distance b/w front and back wheels in car',figsize = (6,4),color = '#3e32a8')
# Out:
# <Axes: xlabel='distance b/w front and back wheels in car', ylabel='Frequency'>

# %% [markdown]
# * There are 81 cars with 95 cm distance b/w the wheels and around 1-2 cars with 120 cm distance b/w wheels and the data is approx. normally distributed in the given data set

# %%
df['length'].plot(kind = 'hist',xlabel = 'length of the car',figsize = (6,4),color = '#7132a8')
# Out:
# <Axes: xlabel='length of the car', ylabel='Frequency'>

# %% [markdown]
# * There are around 52 cars with length of 170-180 cms and 2-3 cars with length of 140-150 cms and the data is following normalization/normal distribution in the given data set

# %% [markdown]
# ### Boxplot

# %%
df['width'].plot(kind = 'box',xlabel = 'width of the car',figsize = (6,4),color = '#a8324c')
# Out:
# <Axes: xlabel='width of the car'>

# %% [markdown]
# * The minimum width of the car is 60 cms and maximum width of the car is 73 cms and the data is following normal distribution in the given data set

# %%
df['height'].plot(kind = 'box',xlabel = 'height of the car',figsize = (6,4),color = '#a89432')
# Out:
# <Axes: xlabel='height of the car'>

# %% [markdown]
# * The minimum height of the car is 47cm and the maximum height of the car is around 60cm and the data is approx. normally distributed

# %%
df['curb_weight'].plot(kind = 'box',xlabel = 'weight of the car',figsize = (6,4),color = '#32a857')
# Out:
# <Axes: xlabel='weight of the car'>

# %% [markdown]
# * The min weight of car is around 1450 kgs and maximum weight of car is 4050/4100 kgs and we can say that the data is not normally distributed in the given data set

# %% [markdown]
# ## Density

# %%
df['num_of_cylinders'].plot(kind = 'kde',xlabel = 'num_of_cylinders in car',figsize = (6,4),color = '#3246a8')
# Out:
# <Axes: ylabel='Density'>

# %%
df['engine_size'].plot(kind = 'kde',xlabel = 'size of the engine',figsize = (6,4),color = '#7532a8')
# Out:
# <Axes: ylabel='Density'>

# %%
df['compression_ratio'].plot(kind = 'kde',xlabel = 'ratio of compression',figsize = (6,4),color = '#3259a8')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Barplot

# %%
df['make'].value_counts().plot(kind = 'bar',xlabel = 'Num. of cars sold from each company',figsize = (6,4),color = '#32a86d')
# Out:
# <Axes: xlabel='Num. of cars sold from each company'>

# %% [markdown]
# * By this we can conclude that Toyata company has high sales and mercury company has lowest sales in the given data set

# %%
df['fuel_type'].value_counts().plot(kind = 'bar',xlabel = 'fuel type of the car',figsize = (6,4),color = '#a83240')
# Out:
# <Axes: xlabel='fuel type of the car'>

# %% [markdown]
# * There are more cars by usage of gas than the cars using diesel in the given data set

# %%
df['aspiration'].value_counts().plot(kind = 'bar',xlabel = 'type of aspirated engine',figsize = (6,4),color = '#6f32a8')
# Out:
# <Axes: xlabel='type of aspirated engine'>

# %% [markdown]
# * The standard engined cars are more than the turbo engined cars in the given data set

# %% [markdown]
# ## Pie chart

# %%
(df['body_style'].value_counts()/len(df['body_style']) * 100).plot(kind = 'pie',autopct = '%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * There are more sedan styled cars and low convertible(i.e roof convertible)cars in the given data set

# %%
(df['drive_wheels'].value_counts()/len(df['drive_wheels']) * 100).plot(kind = 'pie',autopct = '%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * There are less 4 wheel drive cars and more front wheel drive cars in the given data set

# %%
(df['engine_location'].value_counts()/len(df['engine_location']) * 100).plot(kind = 'pie',autopct = '%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * By this we can say that front engined cars are more greater than rear engine cars in the given data set

# %% [markdown]
# ## Count plot

# %%
sns.countplot(data = df,x = 'fuel_system')
# Out:
# <Axes: xlabel='fuel_system', ylabel='count'>

# %%
sns.countplot(data = df,x = 'engine_type')
# Out:
# <Axes: xlabel='engine_type', ylabel='count'>

# %% [markdown]
# ## Bivariate analysis

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors           int64
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders        int8
# engine_size          float64
# fuel_system           object
# compression_ratio    float64
# horsepower             int16
# peak_rpm               int16
# city_mpg               int64
# highway_mpg            int64
# price                  int64
# dtype: object

# %% [markdown]
# ### 1.Categorical & Categorical

# %% [markdown]
# ### cross tab

# %%
pd.crosstab(df['make'],df['fuel_type'])
# Out:
# fuel_type      diesel  gas
# make
# alfa-romero         0    3
# audi                0    7
# bmw                 0    8
# chevrolet           0    3
# dodge               0    9
# honda               0   13
# isuzu               0    4
# jaguar              0    3
# mazda               2   15
# mercedes-benz       4    4
# mercury             0    1
# mitsubishi          0   13
# nissan              1   17
# peugot              5    6
# plymouth            0    7
# porsche             0    5
# renault             0    2
# saab                0    6
# subaru              0   12
# toyota              3   29
# volkswagen          4    8
# volvo               1   10

# %% [markdown]
# * By this we can say that how many diesel cars and how many gas cars from the each company in the given dataset

# %%
pd.crosstab(df['aspiration'],df['body_style'])
# Out:
# body_style  convertible  hardtop  hatchback  sedan  wagon
# aspiration
# std                   6        7         57     78     20
# turbo                 0        1         13     18      5

# %% [markdown]
# * By this we can conclude that how many cars are with different type of aspirated engine with different body styles

# %% [markdown]
# ### count plot

# %%
sns.countplot(data=df,x = 'drive_wheels',hue = 'engine_location')
# Out:
# <Axes: xlabel='drive_wheels', ylabel='count'>

# %% [markdown]
# * From this we can say that there are more front engined cars and low rear engined cars and more front wheel drive cars and low 4 wheel drive cars in the given dataset

# %%
sns.countplot(data=df,x = 'engine_type',hue = 'fuel_system')
# Out:
# <Axes: xlabel='engine_type', ylabel='count'>

# %% [markdown]
# * From this we can say that 2bbl fuel system cars are more in ohc engine type  and ohc engine typed cars are more in the given dataset

# %% [markdown]
# ## 2.Numerical and numerical

# %% [markdown]
# ### Correlation

# %%
df.corr(numeric_only=True)
# Out:
#                    num_of_doors  wheel_base    length     width    height  \
# num_of_doors           1.000000    0.434334  0.385675  0.197735  0.540286
# wheel_base             0.434334    1.000000  0.871674  0.795635  0.586421
# length                 0.385675    0.871674  1.000000  0.841118  0.491029
# width                  0.197735    0.795635  0.841118  1.000000  0.279210
# height                 0.540286    0.586421  0.491029  0.279210  1.000000
# curb_weight            0.190720    0.775265  0.877728  0.867032  0.295572
# num_of_cylinders      -0.019503    0.340349  0.430672  0.545007 -0.013995
# engine_size            0.017968    0.567020  0.682920  0.733872  0.067997
# compression_ratio      0.171797    0.250870  0.158414  0.181129  0.261214
# horsepower            -0.127846    0.351295  0.553337  0.641337 -0.109286
# peak_rpm              -0.240473   -0.364688 -0.286362 -0.219374 -0.321113
# city_mpg              -0.014271   -0.467683 -0.670909 -0.642704 -0.048640
# ...

# %% [markdown]
# * By observing the above dataset we can conclude that this is the correlation between all the numerical datatypes in the given dataset

# %% [markdown]
# ### Scatterplot

# %%
df.plot('height','wheel_base',kind = 'scatter')
# Out:
# <Axes: xlabel='height', ylabel='wheel_base'>

# %% [markdown]
# * This plot says that the relation between height of the car and wheel base , and these two columns are having positive moderate relationship in the given dataset

# %%
df.plot('length','engine_size',kind = 'scatter')
# Out:
# <Axes: xlabel='length', ylabel='engine_size'>

# %% [markdown]
# * This plot says that the relation between length of the car and engine size , and these two columns are having positive strong relationship in the given dataset

# %%
df.plot('horsepower','price',kind = 'scatter')
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>

# %% [markdown]
# * This plot says that the relation between price of the car and horse power of the car , and these two columns are having positive strong relationship in the given dataset

# %%
df.plot('curb_weight','highway_mpg',kind = 'scatter')
# Out:
# <Axes: xlabel='curb_weight', ylabel='highway_mpg'>

# %% [markdown]
# * This plot says that the relation between curb weight of the car and mileage of the car , and these two columns are having negative moderate relationship in the given dataset

# %% [markdown]
# ## 3.categorical and numerical

# %% [markdown]
# ### group by

# %%
df.groupby(by = 'engine_type')['price'].min()
# Out:
# engine_type
# dohc      9298
# dohcv    10221
# l         5151
# ohc       5195
# ohcf      5118
# ohcv     13499
# rotor    10945
# Name: price, dtype: int64

# %% [markdown]
# * By this we can conclude that what is the minimum price of a car by the specific engine types in the given dataset

# %%
df.groupby(by = 'fuel_type')['price'].mean()
# Out:
# fuel_type
# diesel    14891.750000
# gas       12739.054054
# Name: price, dtype: float64

# %% [markdown]
# * By this we can conclude that what is the average price of a car by the fuel type(i.e gas / diesel) in the given dataset

# %%
df.groupby(by = 'fuel_system')['compression_ratio'].mean()
# Out:
# fuel_system
# 1bbl     9.245455
# 2bbl     9.088030
# 4bbl     9.400000
# idi     22.005000
# mfi      7.000000
# mpfi     8.803298
# spdi     7.300000
# spfi     9.200000
# Name: compression_ratio, dtype: float64

# %% [markdown]
# * By this we can conclude that what is the average compression ratio of a car by the fuel_system of the car in the given dataset

# %%
df.groupby(by = 'fuel_type')['highway_mpg'].max()
# Out:
# fuel_type
# diesel    50
# gas       54
# Name: highway_mpg, dtype: int64

# %% [markdown]
# * By this we can conclude that what is the maximum mileage of a car by specific fuel_type in the given dataset

# %% [markdown]
# ### line chart

# %%
sns.lineplot(x="wheel_base", y="body_style", data=df)
# Out:
# <Axes: xlabel='wheel_base', ylabel='body_style'>

# %% [markdown]
# * By above line chart we can say that what is the wheel base of different body styles in the given dataset

# %%
sns.lineplot(x="length", y="engine_type", data=df)
# Out:
# <Axes: xlabel='length', ylabel='engine_type'>

# %% [markdown]
# * From this we can say that what is the length of the car with different engine types in the given dataset

# %%
sns.lineplot(x="peak_rpm", y="fuel_system", data=df)
# Out:
# <Axes: xlabel='peak_rpm', ylabel='fuel_system'>

# %% [markdown]
# * From this we can say that what are the peak revolutions per minute of the car with different fuel systems in the given dataset

# %% [markdown]
# ## multivariate analysis

# %%
sns.heatmap(df.corr(numeric_only = True), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# * From above heatmap we can say that what is the correlation between all the numerical datatypes in the given dataset using seaborn library

# %% [markdown]
# ### using seaborn

# %%
sns.pairplot(df)

# %% [markdown]
# * The above figure shows the pairing of histogram and scatter plot of given dataset

# %%
sns.histplot(df['length'])
# Out:
# <Axes: xlabel='length', ylabel='Count'>

# %% [markdown]
# * From this we can say the length of the car is following normal distribution (not exactly) in the given dataset

# %%
sns.kdeplot(df['highway_mpg'])
# Out:
# <Axes: xlabel='highway_mpg', ylabel='Density'>

# %% [markdown]
# * From this we can say the highway_mpg is following normal distribution (not exactly) but apart of normal distribution with some disturbances in dendity in the given dataset

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors           int64
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders        int8
# engine_size          float64
# fuel_system           object
# compression_ratio    float64
# horsepower             int16
# peak_rpm               int16
# city_mpg               int64
# highway_mpg            int64
# price                  int64
# dtype: object

# %%
sns.boxplot(df['peak_rpm'])
# Out:
# <Axes: ylabel='peak_rpm'>

# %% [markdown]
# * From this we can say that the peak rpm of the car is following normal distribution (not exactly) in the given dataset

# %%
sns.distplot(df['curb_weight'])
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_28072\3952843952.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['curb_weight'])
# <Axes: xlabel='curb_weight', ylabel='Density'>

# %% [markdown]
# * From this we can say the curb_weight is following normal distribution (not exactly) but apart of normal distribution in the given dataset

# %% [markdown]
# * And this is the combination of histogram and density plot
